# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('customers-100.csv')
df
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ..                              ...                ...
# 95                        Carey LLC       East Richard
# 96            Ware, Burns and Oneal       New Bradview
# 97                    Schmitt-Jones         Ortegaland
# 98               Fitzgerald-Harrell    Lake Elijahview
# 99               Le, Nash and Cross          Judymouth
#
#                        Country                 Phone 1  Unnamed: 8  \
# 0                        Chile            229.077.5154         NaN
# 1                     Djibouti              5153435776         NaN
# 2          Antigua and Barbuda                   -1199         NaN
# 3           Dominican Republic  001-808-617-6467x12895         NaN
# 4   Slovakia (Slovak Republic)  001-234-203-0635x76146         NaN
# ..                         ...                     ...         ...
# 95                      Guyana     (188)169-1674x58692         NaN
# 96                   Sri Lanka                   -3769         NaN
# 97             Solomon Islands    +1-753-067-8419x7170         NaN
# 98                       Aruba           (530)311-9786         NaN
# 99                    Honduras           (753)813-6941         NaN
#
#                              Email  Unnamed: 10
# 0         zunigavanessa@smith.info          NaN
# 1                  vmata@colon.com          NaN
# 2              beckycarr@hogan.com          NaN
# 3      stanleyblackwell@benson.org          NaN
# 4          colinalvarado@miles.net          NaN
# ..                             ...          ...
# 95                hhart@jensen.com          NaN
# 96               vkemp@ferrell.com          NaN
# 97                swagner@kane.org          NaN
# 98  mccarthystephen@horn-green.biz          NaN
# 99          colleen91@faulkner.biz          NaN
#
# [100 rows x 11 columns]

# %%
df.isnull()
# Out:
#     Index  Customer Id  First Name  Last Name  Company   City  Country  \
# 0   False        False       False      False    False  False    False
# 1   False        False       False      False    False  False    False
# 2   False        False       False      False    False  False    False
# 3   False        False       False      False    False  False    False
# 4   False        False       False      False    False  False    False
# ..    ...          ...         ...        ...      ...    ...      ...
# 95  False        False       False      False    False  False    False
# 96  False        False       False      False    False  False    False
# 97  False        False       False      False    False  False    False
# 98  False        False       False      False    False  False    False
# 99  False        False       False      False    False  False    False
#
#     Phone 1  Unnamed: 8  Email  Unnamed: 10
# 0     False        True  False         True
# 1     False        True  False         True
# 2     False        True  False         True
# 3     False        True  False         True
# 4     False        True  False         True
# ..      ...         ...    ...          ...
# 95    False        True  False         True
# 96    False        True  False         True
# 97    False        True  False         True
# 98    False        True  False         True
# 99    False        True  False         True
#
# [100 rows x 11 columns]

# %%
df.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1  Unnamed: 8  \
# 0                       Chile            229.077.5154         NaN
# 1                    Djibouti              5153435776         NaN
# 2         Antigua and Barbuda                   -1199         NaN
# 3          Dominican Republic  001-808-617-6467x12895         NaN
# 4  Slovakia (Slovak Republic)  001-234-203-0635x76146         NaN
#
#                          Email  Unnamed: 10
# 0     zunigavanessa@smith.info          NaN
# 1              vmata@colon.com          NaN
# 2          beckycarr@hogan.com          NaN
# 3  stanleyblackwell@benson.org          NaN
# 4      colinalvarado@miles.net          NaN

# %%
df.describe()
# Out:
#             Index  Unnamed: 8  Unnamed: 10
# count  100.000000         0.0          0.0
# mean    50.500000         NaN          NaN
# std     29.011492         NaN          NaN
# min      1.000000         NaN          NaN
# 25%     25.750000         NaN          NaN
# 50%     50.500000         NaN          NaN
# 75%     75.250000         NaN          NaN
# max    100.000000         NaN          NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Index        100 non-null    int64
#  1   Customer Id  100 non-null    object
#  2   First Name   100 non-null    object
#  3   Last Name    100 non-null    object
#  4   Company      100 non-null    object
#  5   City         100 non-null    object
#  6   Country      100 non-null    object
#  7   Phone 1      100 non-null    object
#  8   Unnamed: 8   0 non-null      float64
#  9   Email        100 non-null    object
#  10  Unnamed: 10  0 non-null      float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 8.7+ KB

# %%
df_size = df.size
df_size

df_shape = df.shape
df_shape
# Out:
# (100, 11)

# %%
df_ndim = df.ndim
series_ndim = df['name'].ndim
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 2
#       1 df_ndim = df.ndim
# ----> 2 series_ndim = df['name'].ndim
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'name'

# %%
print("Size = {}\n Shape = {}\nShape[0] x Shape[1] = {}".format(df_size, df_shape, df_shape[0]*df_shape[1]))

# %%
print("ndim of Dataframe = {}\nndim of series = {}" .format(df_ndim, series_ndim))

# %%
df_dtypes = df.dtypes
df_dtypes
# Out:
# Index            int64
# Customer Id     object
# First Name      object
# Last Name       object
# Company         object
# City            object
# Country         object
# Phone 1         object
# Unnamed: 8     float64
# Email           object
# Unnamed: 10    float64
# dtype: object

# %%
dummies = pd.get_dummies(df.City)
merged = pd.concat([df, dummies], axis = 'columns')

df
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ..                              ...                ...
# 95                        Carey LLC       East Richard
# 96            Ware, Burns and Oneal       New Bradview
# 97                    Schmitt-Jones         Ortegaland
# 98               Fitzgerald-Harrell    Lake Elijahview
# 99               Le, Nash and Cross          Judymouth
#
#                        Country                 Phone 1  Unnamed: 8  \
# 0                        Chile            229.077.5154         NaN
# 1                     Djibouti              5153435776         NaN
# 2          Antigua and Barbuda                   -1199         NaN
# 3           Dominican Republic  001-808-617-6467x12895         NaN
# 4   Slovakia (Slovak Republic)  001-234-203-0635x76146         NaN
# ..                         ...                     ...         ...
# 95                      Guyana     (188)169-1674x58692         NaN
# 96                   Sri Lanka                   -3769         NaN
# 97             Solomon Islands    +1-753-067-8419x7170         NaN
# 98                       Aruba           (530)311-9786         NaN
# 99                    Honduras           (753)813-6941         NaN
#
#                              Email  Unnamed: 10
# 0         zunigavanessa@smith.info          NaN
# 1                  vmata@colon.com          NaN
# 2              beckycarr@hogan.com          NaN
# 3      stanleyblackwell@benson.org          NaN
# 4          colinalvarado@miles.net          NaN
# ..                             ...          ...
# 95                hhart@jensen.com          NaN
# 96               vkemp@ferrell.com          NaN
# 97                swagner@kane.org          NaN
# 98  mccarthystephen@horn-green.biz          NaN
# 99          colleen91@faulkner.biz          NaN
#
# [100 rows x 11 columns]
